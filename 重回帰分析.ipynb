# %% [markdown]
# <a href="https://colab.research.google.com/github/GentaKanno/Analysis/blob/main/%E9%87%8D%E5%9B%9E%E5%B8%B0%E5%88%86%E6%9E%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import statsmodels.api as sm
import pickle

for i in range(2, 15):

    # Excelデータ読み込み
    df=pd.read_excel("分析用.xlsx", sheet_name=f"Sheet{i}")

    # Excel側に存在する列名
    excel_cols=set(df.columns)

    # 元の候補列リスト
    candidate_cols=["縦横比","縦横比sq","45°縦横比","45°縦横比sq","黒画素エントロピー","黒画素エントロピーsq","黒画素上下比","黒画素上下比sq","黒画素左右比","黒画素左右比sq","黒画素対角比","黒画素対角比sq","距離エントロピー","距離エントロピーsq","角度標準偏差","角度標準偏差sq","x距離差","x距離差sq","y距離差","y距離差sq","部分系長さ","部分系長さsq","部分系面積","部分系面積sq","ストローク長さ","ストローク長さsq","ストローク面積","ストローク面積sq"]

    # 共通する列だけ抽出
    selected_cols=[col for col in candidate_cols if col in excel_cols]

    # Xデータフレーム作成
    X=df[selected_cols]

    # 目的変数用データフレーム作成
    Y=df[["評価値"]]

    # 切片項追加
    X=sm.add_constant(X)

    # 重回帰モデル作成
    model=sm.OLS(Y,X).fit()

    # モデルをpklファイルで保存
    with open(f"model{i}.pkl","wb") as f:
        pickle.dump(model,f)

    # モデル作成結果を表示
    print(model.summary())

    # モデル作成結果をcsvファイルで出力
    # モデル作成結果を文字列に変換
    summary_txt=model.summary().as_text()
    # 作成結果の文字列を改行で分割しリスト化
    summary_lines=summary_txt.split("\n")
    # 作成結果のリストをデータフレーム化
    summary_df=pd.DataFrame(summary_lines)
    # 作成結果のcsvファイルとして出力
    summary_df.to_csv(f"summary{i}.csv",index=False,header=False,encoding="utf-8-sig")
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    評価値   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):                nan
# Time:                        07:40:20   Log-Likelihood:                 193.96
# No. Observations:                   6   AIC:                            -375.9
# Df Residuals:                       0   BIC:                            -377.2
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0354        inf          0        nan         nan         nan
# 縦横比             0.1013        inf          0        nan         nan         nan
# 縦横比sq           0.2072        inf          0        nan         nan         nan
# 45°縦横比         -0.0168        inf         -0        nan         nan         nan
# 45°縦横比sq       -0.0808        inf         -0        nan         nan         nan
# 黒画素エントロピー       0.0421        inf          0        nan         nan         nan
# 黒画素エントロピーsq     0.0299        inf          0        nan         nan         nan
# 黒画素上下比         -0.0408        inf         -0        nan         nan         nan
# 黒画素上下比sq       -0.0581        inf         -0        nan         nan         nan
# 黒画素左右比          0.1430        inf          0        nan         nan         nan
# 黒画素左右比sq        0.3311        inf          0        nan         nan         nan
# 黒画素対角比          0.0691        inf          0        nan         nan         nan
# 黒画素対角比sq        0.1119        inf          0        nan         nan         nan
# 距離エントロピー        0.0675        inf          0        nan         nan         nan
# 距離エントロピーsq      0.1285        inf          0        nan         nan         nan
# 角度標準偏差          0.0002        inf          0        nan         nan         nan
# 角度標準偏差sq       -0.1692        inf         -0        nan         nan         nan
# x距離差            0.1983        inf          0        nan         nan         nan
# x距離差sq         -0.0263        inf         -0        nan         nan         nan
# y距離差            0.2199        inf          0        nan         nan         nan
# y距離差sq          0.0061        inf          0        nan         nan         nan
# ストローク長さ         0.0558        inf          0        nan         nan         nan
# ストローク長さsq       0.0857        inf          0        nan         nan         nan
# ストローク面積        -0.0056        inf         -0        nan         nan         nan
# ストローク面積sq      -0.0689        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.408
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.254
# Skew:                           1.116   Prob(JB):                        0.534
# Kurtosis:                       2.825   Cond. No.                         476.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    評価値   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):                nan
# Time:                        07:40:20   Log-Likelihood:                 178.24
# No. Observations:                   6   AIC:                            -344.5
# Df Residuals:                       0   BIC:                            -345.7
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0510        inf         -0        nan         nan         nan
# 縦横比            -0.0555        inf         -0        nan         nan         nan
# 縦横比sq          -0.0510        inf         -0        nan         nan         nan
# 45°縦横比         -0.1117        inf         -0        nan         nan         nan
# 45°縦横比sq       -0.2247        inf         -0        nan         nan         nan
# 黒画素エントロピー      -0.1251        inf         -0        nan         nan         nan
# 黒画素エントロピーsq    -0.2852        inf         -0        nan         nan         nan
# 黒画素上下比          0.0226        inf          0        nan         nan         nan
# 黒画素上下比sq        0.0928        inf          0        nan         nan         nan
# 黒画素左右比         -0.0298        inf         -0        nan         nan         nan
# 黒画素左右比sq        0.0958        inf          0        nan         nan         nan
# 黒画素対角比         -0.0237        inf         -0        nan         nan         nan
# 黒画素対角比sq        0.0496        inf          0        nan         nan         nan
# 距離エントロピー       -0.1026        inf         -0        nan         nan         nan
# 距離エントロピーsq     -0.2065        inf         -0        nan         nan         nan
# 角度標準偏差         -0.1638        inf         -0        nan         nan         nan
# 角度標準偏差sq       -0.5012        inf         -0        nan         nan         nan
# x距離差            0.4147        inf          0        nan         nan         nan
# x距離差sq         -0.0034        inf         -0        nan         nan         nan
# y距離差            0.0897        inf          0        nan         nan         nan
# y距離差sq         -0.0042        inf         -0        nan         nan         nan
# 部分系長さ          -0.0298        inf         -0        nan         nan         nan
# 部分系長さsq         0.0958        inf          0        nan         nan         nan
# 部分系面積          -0.1555        inf         -0        nan         nan         nan
# 部分系面積sq         0.0406        inf          0        nan         nan         nan
# ストローク長さ        -0.0298        inf         -0        nan         nan         nan
# ストローク長さsq       0.0958        inf          0        nan         nan         nan
# ストローク面積        -0.2153        inf         -0        nan         nan         nan
# ストローク面積sq      -0.0507        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.987
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.752
# Skew:                          -0.537   Prob(JB):                        0.687
# Kurtosis:                       1.637   Cond. No.                     6.08e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 6.08e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    評価値   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):                nan
# Time:                        07:40:21   Log-Likelihood:                 180.73
# No. Observations:                   6   AIC:                            -349.5
# Df Residuals:                       0   BIC:                            -350.7
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0384        inf         -0        nan         nan         nan
# 縦横比            -0.0134        inf         -0        nan         nan         nan
# 縦横比sq           0.0811        inf          0        nan         nan         nan
# 45°縦横比         -0.0557        inf         -0        nan         nan         nan
# 45°縦横比sq       -0.0672        inf         -0        nan         nan         nan
# 黒画素エントロピー      -0.0737        inf         -0        nan         nan         nan
# 黒画素エントロピーsq    -0.1424        inf         -0        nan         nan         nan
# 黒画素上下比         -0.0104        inf         -0        nan         nan         nan
# 黒画素上下比sq       -0.0026        inf         -0        nan         nan         nan
# 黒画素左右比         -0.0584        inf         -0        nan         nan         nan
# 黒画素左右比sq       -0.0707        inf         -0        nan         nan         nan
# 黒画素対角比         -0.0391        inf         -0        nan         nan         nan
# 黒画素対角比sq       -0.0399        inf         -0        nan         nan         nan
# 距離エントロピー       -0.0713        inf         -0        nan         nan         nan
# 距離エントロピーsq     -0.1320        inf         -0        nan         nan         nan
# 角度標準偏差         -0.1370        inf         -0        nan         nan         nan
# 角度標準偏差sq       -0.4072        inf         -0        nan         nan         nan
# x距離差           -0.3325        inf         -0        nan         nan         nan
# x距離差sq         -0.0107        inf         -0        nan         nan         nan
# y距離差            0.0538        inf          0        nan         nan         nan
# y距離差sq       4.563e-05        inf          0        nan         nan         nan
# 部分系長さ           0.0150        inf          0        nan         nan         nan
# 部分系長さsq         0.1264        inf          0        nan         nan         nan
# 部分系面積           0.0895        inf          0        nan         nan         nan
# 部分系面積sq        -0.0006        inf         -0        nan         nan         nan
# ストローク長さ        -0.0419        inf         -0        nan         nan         nan
# ストローク長さsq      -0.0320        inf         -0        nan         nan         nan
# ストローク面積        -0.0533        inf         -0        nan         nan         nan
# ストローク面積sq      -0.0420        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.320
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.570
# Skew:                           0.417   Prob(JB):                        0.752
# Kurtosis:                       1.742   Cond. No.                     1.71e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 1.71e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    評価値   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):                nan
# Time:                        07:40:21   Log-Likelihood:                 176.08
# No. Observations:                   6   AIC:                            -340.2
# Df Residuals:                       0   BIC:                            -341.4
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0032        inf         -0        nan         nan         nan
# 縦横比            -0.0052        inf         -0        nan         nan         nan
# 縦横比sq          -0.0082        inf         -0        nan         nan         nan
# 45°縦横比         -0.0020        inf         -0        nan         nan         nan
# 45°縦横比sq       -0.0013        inf         -0        nan         nan         nan
# 黒画素エントロピー      -0.0051        inf         -0        nan         nan         nan
# 黒画素エントロピーsq    -0.0094        inf         -0        nan         nan         nan
# 黒画素上下比         -0.0008        inf         -0        nan         nan         nan
# 黒画素上下比sq       -0.0007        inf         -0        nan         nan         nan
# 黒画素左右比          0.0035        inf          0        nan         nan         nan
# 黒画素左右比sq        0.0290        inf          0        nan         nan         nan
# 黒画素対角比         -0.0068        inf         -0        nan         nan         nan
# 黒画素対角比sq       -0.0126        inf         -0        nan         nan         nan
# 距離エントロピー       -0.0056        inf         -0        nan         nan         nan
# 距離エントロピーsq     -0.0105        inf         -0        nan         nan         nan
# 角度標準偏差         -0.0052        inf         -0        nan         nan         nan
# 角度標準偏差sq       -0.0117        inf         -0        nan         nan         nan
# x距離差           -0.0326        inf         -0        nan         nan         nan
# x距離差sq         -0.0013        inf         -0        nan         nan         nan
# y距離差           -0.1267        inf         -0        nan         nan         nan
# y距離差sq         -0.0032        inf         -0        nan         nan         nan
# 部分系長さ          -0.0042        inf         -0        nan         nan         nan
# 部分系長さsq        -0.0145        inf         -0        nan         nan         nan
# 部分系面積           0.0197        inf          0        nan         nan         nan
# 部分系面積sq        -0.0004        inf         -0        nan         nan         nan
# ストローク長さ        -0.0014        inf         -0        nan         nan         nan
# ストローク長さsq      -0.0005        inf         -0        nan         nan         nan
# ストローク面積        -0.0017        inf         -0        nan         nan         nan
# ストローク面積sq      -0.0006        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.800
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.240
# Skew:                          -0.470   Prob(JB):                        0.887
# Kurtosis:                       2.722   Cond. No.                         669.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    評価値   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):                nan
# Time:                        07:40:21   Log-Likelihood:                 176.51
# No. Observations:                   6   AIC:                            -341.0
# Df Residuals:                       0   BIC:                            -342.3
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0120        inf          0        nan         nan         nan
# 縦横比             0.0035        inf          0        nan         nan         nan
# 縦横比sq          -0.0046        inf         -0        nan         nan         nan
# 45°縦横比          0.0216        inf          0        nan         nan         nan
# 45°縦横比sq        0.0333        inf          0        nan         nan         nan
# 黒画素エントロピー       0.0201        inf          0        nan         nan         nan
# 黒画素エントロピーsq     0.0332        inf          0        nan         nan         nan
# 黒画素上下比          0.0127        inf          0        nan         nan         nan
# 黒画素上下比sq        0.0179        inf          0        nan         nan         nan
# 黒画素左右比          0.0365        inf          0        nan         nan         nan
# 黒画素左右比sq        0.1062        inf          0        nan         nan         nan
# 黒画素対角比          0.0054        inf          0        nan         nan         nan
# 黒画素対角比sq       -0.0002        inf         -0        nan         nan         nan
# 距離エントロピー        0.0234        inf          0        nan         nan         nan
# 距離エントロピーsq      0.0457        inf          0        nan         nan         nan
# 角度標準偏差          0.0357        inf          0        nan         nan         nan
# 角度標準偏差sq        0.0958        inf          0        nan         nan         nan
# x距離差           -0.0322        inf         -0        nan         nan         nan
# x距離差sq          0.0032        inf          0        nan         nan         nan
# y距離差           -0.0775        inf         -0        nan         nan         nan
# y距離差sq         -0.0108        inf         -0        nan         nan         nan
# 部分系長さ           0.0497        inf          0        nan         nan         nan
# 部分系長さsq        -0.0006        inf         -0        nan         nan         nan
# 部分系面積          -0.2406        inf         -0        nan         nan         nan
# 部分系面積sq         0.0019        inf          0        nan         nan         nan
# ストローク長さ         0.0132        inf          0        nan         nan         nan
# ストローク長さsq       0.0143        inf          0        nan         nan         nan
# ストローク面積         0.0010        inf          0        nan         nan         nan
# ストローク面積sq      -0.0055        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.666
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                3.186
# Skew:                           1.706   Prob(JB):                        0.203
# Kurtosis:                       4.049   Cond. No.                     3.77e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 3.77e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    評価値   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):                nan
# Time:                        07:40:21   Log-Likelihood:                 173.62
# No. Observations:                   6   AIC:                            -335.2
# Df Residuals:                       0   BIC:                            -336.5
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0245        inf         -0        nan         nan         nan
# 縦横比            -0.0504        inf         -0        nan         nan         nan
# 縦横比sq          -0.0786        inf         -0        nan         nan         nan
# 45°縦横比         -0.0292        inf         -0        nan         nan         nan
# 45°縦横比sq       -0.0375        inf         -0        nan         nan         nan
# 黒画素エントロピー      -0.0530        inf         -0        nan         nan         nan
# 黒画素エントロピーsq    -0.1146        inf         -0        nan         nan         nan
# 黒画素上下比         -0.0396        inf         -0        nan         nan         nan
# 黒画素上下比sq       -0.0807        inf         -0        nan         nan         nan
# 黒画素左右比          0.0490        inf          0        nan         nan         nan
# 黒画素左右比sq        0.2430        inf          0        nan         nan         nan
# 黒画素対角比         -0.0272        inf         -0        nan         nan         nan
# 黒画素対角比sq       -0.0273        inf         -0        nan         nan         nan
# 距離エントロピー       -0.0482        inf         -0        nan         nan         nan
# 距離エントロピーsq     -0.0946        inf         -0        nan         nan         nan
# 角度標準偏差         -0.0589        inf         -0        nan         nan         nan
# 角度標準偏差sq       -0.1484        inf         -0        nan         nan         nan
# x距離差            0.0915        inf          0        nan         nan         nan
# x距離差sq         -0.0079        inf         -0        nan         nan         nan
# y距離差           -0.2496        inf         -0        nan         nan         nan
# y距離差sq          0.0050        inf          0        nan         nan         nan
# 部分系長さ           0.1030        inf          0        nan         nan         nan
# 部分系長さsq         0.5620        inf          0        nan         nan         nan
# 部分系面積          -0.0411        inf         -0        nan         nan         nan
# 部分系面積sq        -0.0490        inf         -0        nan         nan         nan
# ストローク長さ        -0.0387        inf         -0        nan         nan         nan
# ストローク長さsq      -0.0612        inf         -0        nan         nan         nan
# ストローク面積        -0.0330        inf         -0        nan         nan         nan
# ストローク面積sq      -0.0443        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.708
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.963
# Skew:                           0.980   Prob(JB):                        0.618
# Kurtosis:                       2.876   Cond. No.                         941.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    評価値   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):                nan
# Time:                        07:40:21   Log-Likelihood:                 186.75
# No. Observations:                   6   AIC:                            -361.5
# Df Residuals:                       0   BIC:                            -362.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0270        inf          0        nan         nan         nan
# 縦横比             0.0982        inf          0        nan         nan         nan
# 縦横比sq           0.2379        inf          0        nan         nan         nan
# 45°縦横比          0.0151        inf          0        nan         nan         nan
# 45°縦横比sq        0.0022        inf          0        nan         nan         nan
# 黒画素エントロピー       0.0544        inf          0        nan         nan         nan
# 黒画素エントロピーsq     0.1096        inf          0        nan         nan         nan
# 黒画素上下比          0.0107        inf          0        nan         nan         nan
# 黒画素上下比sq       -0.0772        inf         -0        nan         nan         nan
# 黒画素左右比          0.0126        inf          0        nan         nan         nan
# 黒画素左右比sq        0.0043        inf          0        nan         nan         nan
# 黒画素対角比          0.0335        inf          0        nan         nan         nan
# 黒画素対角比sq        0.0544        inf          0        nan         nan         nan
# 距離エントロピー        0.0515        inf          0        nan         nan         nan
# 距離エントロピーsq      0.0981        inf          0        nan         nan         nan
# 角度標準偏差          0.0300        inf          0        nan         nan         nan
# 角度標準偏差sq       -0.0188        inf         -0        nan         nan         nan
# x距離差           -0.4689        inf         -0        nan         nan         nan
# x距離差sq          0.0363        inf          0        nan         nan         nan
# y距離差            0.1709        inf          0        nan         nan         nan
# y距離差sq         -0.0100        inf         -0        nan         nan         nan
# 部分系長さ           0.0645        inf          0        nan         nan         nan
# 部分系長さsq         0.1763        inf          0        nan         nan         nan
# 部分系面積          -0.0047        inf         -0        nan         nan         nan
# 部分系面積sq        -0.3597        inf         -0        nan         nan         nan
# ストローク長さ         0.0533        inf          0        nan         nan         nan
# ストローク長さsq       0.1054        inf          0        nan         nan         nan
# ストローク面積         0.0478        inf          0        nan         nan         nan
# ストローク面積sq       0.0838        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.072
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.308
# Skew:                          -0.555   Prob(JB):                        0.857
# Kurtosis:                       2.984   Cond. No.                         824.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    評価値   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):                nan
# Time:                        07:40:21   Log-Likelihood:                 159.20
# No. Observations:                   6   AIC:                            -306.4
# Df Residuals:                       0   BIC:                            -307.7
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.1797        inf          0        nan         nan         nan
# 縦横比            -0.8112        inf         -0        nan         nan         nan
# 縦横比sq          -3.3530        inf         -0        nan         nan         nan
# 45°縦横比          0.7071        inf          0        nan         nan         nan
# 45°縦横比sq        1.1936        inf          0        nan         nan         nan
# 黒画素エントロピー       0.4983        inf          0        nan         nan         nan
# 黒画素エントロピーsq     1.2294        inf          0        nan         nan         nan
# 黒画素上下比          0.8997        inf          0        nan         nan         nan
# 黒画素上下比sq        1.3920        inf          0        nan         nan         nan
# 黒画素左右比         -0.8520        inf         -0        nan         nan         nan
# 黒画素左右比sq       -3.1332        inf         -0        nan         nan         nan
# 黒画素対角比         -0.3577        inf         -0        nan         nan         nan
# 黒画素対角比sq       -0.3110        inf         -0        nan         nan         nan
# 距離エントロピー        0.4882        inf          0        nan         nan         nan
# 距離エントロピーsq      1.1532        inf          0        nan         nan         nan
# 角度標準偏差         -0.1305        inf         -0        nan         nan         nan
# 角度標準偏差sq       -1.0317        inf         -0        nan         nan         nan
# x距離差            0.5958        inf          0        nan         nan         nan
# x距離差sq          0.0193        inf          0        nan         nan         nan
# y距離差           -1.0151        inf         -0        nan         nan         nan
# y距離差sq         -0.0115        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.849
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.855
# Skew:                          -1.338   Prob(JB):                        0.396
# Kurtosis:                       3.504   Cond. No.                     6.80e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 6.8e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    評価値   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):                nan
# Time:                        07:40:22   Log-Likelihood:                 189.20
# No. Observations:                   6   AIC:                            -366.4
# Df Residuals:                       0   BIC:                            -367.7
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0064        inf          0        nan         nan         nan
# 縦横比             0.0331        inf          0        nan         nan         nan
# 縦横比sq           0.0516        inf          0        nan         nan         nan
# 45°縦横比         -0.0203        inf         -0        nan         nan         nan
# 45°縦横比sq       -0.0525        inf         -0        nan         nan         nan
# 黒画素エントロピー       0.0181        inf          0        nan         nan         nan
# 黒画素エントロピーsq     0.0442        inf          0        nan         nan         nan
# 黒画素上下比          0.0868        inf          0        nan         nan         nan
# 黒画素上下比sq        0.1176        inf          0        nan         nan         nan
# 黒画素左右比         -0.0838        inf         -0        nan         nan         nan
# 黒画素左右比sq       -0.1664        inf         -0        nan         nan         nan
# 黒画素対角比         -0.0333        inf         -0        nan         nan         nan
# 黒画素対角比sq       -0.1206        inf         -0        nan         nan         nan
# 距離エントロピー        0.0312        inf          0        nan         nan         nan
# 距離エントロピーsq      0.0977        inf          0        nan         nan         nan
# 角度標準偏差         -0.0923        inf         -0        nan         nan         nan
# 角度標準偏差sq       -0.4303        inf         -0        nan         nan         nan
# x距離差           -0.2631        inf         -0        nan         nan         nan
# x距離差sq          0.0013        inf          0        nan         nan         nan
# y距離差            0.5184        inf          0        nan         nan         nan
# y距離差sq         -0.0235        inf         -0        nan         nan         nan
# 部分系長さ           0.1374        inf          0        nan         nan         nan
# 部分系長さsq        -0.0458        inf         -0        nan         nan         nan
# 部分系面積           0.4313        inf          0        nan         nan         nan
# 部分系面積sq         0.2320        inf          0        nan         nan         nan
# ストローク長さ         0.0552        inf          0        nan         nan         nan
# ストローク長さsq       0.1523        inf          0        nan         nan         nan
# ストローク面積         0.0610        inf          0        nan         nan         nan
# ストローク面積sq       0.1369        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.352
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.574
# Skew:                          -0.290   Prob(JB):                        0.751
# Kurtosis:                       1.600   Cond. No.                     3.42e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 3.42e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# ...
# 角度標準偏差         -0.0004        inf         -0        nan         nan         nan
# 角度標準偏差sq        0.1920        inf          0        nan         nan         nan
# x距離差           -0.3599        inf         -0        nan         nan         nan
# x距離差sq          0.0059        inf          0        nan         nan         nan
# y距離差           -0.0490        inf         -0        nan         nan         nan
# y距離差sq          0.0006        inf          0        nan         nan         nan
# 部分系長さ          -0.0644        inf         -0        nan         nan         nan
# 部分系長さsq        -0.1220        inf         -0        nan         nan         nan
# 部分系面積          -0.0683        inf         -0        nan         nan         nan
# 部分系面積sq        -0.0415        inf         -0        nan         nan         nan
# ストローク長さ         0.0275        inf          0        nan         nan         nan
# ストローク長さsq       0.0664        inf          0        nan         nan         nan
# ストローク面積         0.0497        inf          0        nan         nan         nan
# ストローク面積sq       0.0593        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.565
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.075
# Skew:                          -1.022   Prob(JB):                        0.584
# Kurtosis:                       3.351   Cond. No.                     2.88e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 2.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    評価値   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):                nan
# Time:                        07:40:22   Log-Likelihood:                 170.83
# No. Observations:                   6   AIC:                            -329.7
# Df Residuals:                       0   BIC:                            -330.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0046        inf         -0        nan         nan         nan
# 縦横比             0.0068        inf          0        nan         nan         nan
# 縦横比sq           0.0270        inf          0        nan         nan         nan
# 45°縦横比         -0.0024        inf         -0        nan         nan         nan
# 45°縦横比sq        0.0008        inf          0        nan         nan         nan
# 黒画素エントロピー      -0.0103        inf         -0        nan         nan         nan
# 黒画素エントロピーsq    -0.0227        inf         -0        nan         nan         nan
# 黒画素上下比         -0.0040        inf         -0        nan         nan         nan
# 黒画素上下比sq       -0.0109        inf         -0        nan         nan         nan
# 黒画素左右比          0.0404        inf          0        nan         nan         nan
# 黒画素左右比sq        0.0962        inf          0        nan         nan         nan
# 黒画素対角比         -0.0240        inf         -0        nan         nan         nan
# 黒画素対角比sq       -0.0796        inf         -0        nan         nan         nan
# 距離エントロピー       -0.0092        inf         -0        nan         nan         nan
# 距離エントロピーsq     -0.0182        inf         -0        nan         nan         nan
# 角度標準偏差         -0.0236        inf         -0        nan         nan         nan
# 角度標準偏差sq       -0.1029        inf         -0        nan         nan         nan
# x距離差            0.0420        inf          0        nan         nan         nan
# x距離差sq         -0.0044        inf         -0        nan         nan         nan
# y距離差            0.0118        inf          0        nan         nan         nan
# y距離差sq      -5.932e-05        inf         -0        nan         nan         nan
# 部分系長さ           0.0049        inf          0        nan         nan         nan
# 部分系長さsq         0.0366        inf          0        nan         nan         nan
# 部分系面積           0.0096        inf          0        nan         nan         nan
# 部分系面積sq        -0.0474        inf         -0        nan         nan         nan
# ストローク長さ        -0.0068        inf         -0        nan         nan         nan
# ストローク長さsq      -0.0101        inf         -0        nan         nan         nan
# ストローク面積        -0.0028        inf         -0        nan         nan         nan
# ストローク面積sq       0.0020        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.825
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.402
# Skew:                           0.575   Prob(JB):                        0.818
# Kurtosis:                       2.466   Cond. No.                     3.16e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 3.16e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    評価値   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):                nan
# Time:                        07:40:22   Log-Likelihood:                 169.40
# No. Observations:                   6   AIC:                            -326.8
# Df Residuals:                       0   BIC:                            -328.1
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0423        inf         -0        nan         nan         nan
# 縦横比            -0.0740        inf         -0        nan         nan         nan
# 縦横比sq          -0.1432        inf         -0        nan         nan         nan
# 45°縦横比         -0.0533        inf         -0        nan         nan         nan
# 45°縦横比sq       -0.0635        inf         -0        nan         nan         nan
# 黒画素エントロピー      -0.0787        inf         -0        nan         nan         nan
# 黒画素エントロピーsq    -0.1466        inf         -0        nan         nan         nan
# 黒画素上下比         -0.0352        inf         -0        nan         nan         nan
# 黒画素上下比sq       -0.0254        inf         -0        nan         nan         nan
# 黒画素左右比         -0.0733        inf         -0        nan         nan         nan
# 黒画素左右比sq       -0.2400        inf         -0        nan         nan         nan
# 黒画素対角比         -0.0261        inf         -0        nan         nan         nan
# 黒画素対角比sq       -0.0248        inf         -0        nan         nan         nan
# 距離エントロピー       -0.0745        inf         -0        nan         nan         nan
# 距離エントロピーsq     -0.1329        inf         -0        nan         nan         nan
# 角度標準偏差         -0.0779        inf         -0        nan         nan         nan
# 角度標準偏差sq       -0.1454        inf         -0        nan         nan         nan
# x距離差            0.0577        inf          0        nan         nan         nan
# x距離差sq         -0.0007        inf         -0        nan         nan         nan
# y距離差           -0.2931        inf         -0        nan         nan         nan
# y距離差sq         -0.0021        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.443
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.730
# Skew:                          -1.305   Prob(JB):                        0.421
# Kurtosis:                       3.334   Cond. No.                     9.98e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 9.98e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    評価値   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):                nan
# Time:                        07:40:22   Log-Likelihood:                 172.79
# No. Observations:                   6   AIC:                            -333.6
# Df Residuals:                       0   BIC:                            -334.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0440        inf          0        nan         nan         nan
# 縦横比            -0.0579        inf         -0        nan         nan         nan
# 縦横比sq          -0.6638        inf         -0        nan         nan         nan
# 45°縦横比          0.2582        inf          0        nan         nan         nan
# 45°縦横比sq        0.5610        inf          0        nan         nan         nan
# 黒画素エントロピー      -0.0406        inf         -0        nan         nan         nan
# 黒画素エントロピーsq    -0.2899        inf         -0        nan         nan         nan
# 黒画素上下比          0.0862        inf          0        nan         nan         nan
# 黒画素上下比sq        0.0991        inf          0        nan         nan         nan
# 黒画素左右比         -0.1368        inf         -0        nan         nan         nan
# 黒画素左右比sq       -0.0887        inf         -0        nan         nan         nan
# 黒画素対角比          0.0138        inf          0        nan         nan         nan
# 黒画素対角比sq       -0.0230        inf         -0        nan         nan         nan
# 距離エントロピー        0.0875        inf          0        nan         nan         nan
# 距離エントロピーsq      0.1755        inf          0        nan         nan         nan
# 角度標準偏差          0.0775        inf          0        nan         nan         nan
# 角度標準偏差sq        0.1323        inf          0        nan         nan         nan
# x距離差           -0.0900        inf         -0        nan         nan         nan
# x距離差sq         -0.0327        inf         -0        nan         nan         nan
# y距離差           -0.1799        inf         -0        nan         nan         nan
# y距離差sq          0.0057        inf          0        nan         nan         nan
# ストローク長さ         0.0272        inf          0        nan         nan         nan
# ストローク長さsq      -0.0054        inf         -0        nan         nan         nan
# ストローク面積         0.3332        inf          0        nan         nan         nan
# ストローク面積sq       0.2950        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.818
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                3.486
# Skew:                          -1.773   Prob(JB):                        0.175
# Kurtosis:                       4.171   Cond. No.                     4.18e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 4.18e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
